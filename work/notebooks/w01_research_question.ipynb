# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""
My lane: Refresh / Content Opportunity Scoring

I'm choosing this lane because during the Week-1 discovery notebook, I found that
search_volume has almost no correlation with actual traffic (impressions_90d), and
CTR drops sharply as position worsens. This means many pages might be sitting in
positions where a small improvement could unlock meaningful traffic - exactly what
a refresh-priority score would help identify. It's a natural extension of the
patterns I already found.
"""
# Out:
# "\nMy lane: Refresh / Content Opportunity Scoring\n\nI'm choosing this lane because during the Week-1 discovery notebook, I found that \nsearch_volume has almost no correlation with actual traffic (impressions_90d), and \nCTR drops sharply as position worsens. This means many pages might be sitting in \npositions where a small improvement could unlock meaningful traffic - exactly what \na refresh-priority score would help identify. It's a natural extension of the \npatterns I already found.\n"

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"""
Decision: Which content pages should the SEO/content team prioritize for a refresh
this quarter, given limited time and resources?

Action: The team uses a ranked "refresh opportunity" list to decide which pages to
update first - rewriting content, improving structure, or targeting better keywords.

Cost of a wrong recommendation: If we flag a low-opportunity page as high-priority,
we waste time and budget refreshing something unlikely to move traffic. If we miss a
genuinely high-opportunity page (good search volume, poor position, low CTR), we lose
out on traffic that could have been captured with a small effort - a real opportunity cost.
"""
# Out:
# '\nDecision: Which content pages should the SEO/content team prioritize for a refresh \nthis quarter, given limited time and resources?\n\nAction: The team uses a ranked "refresh opportunity" list to decide which pages to \nupdate first - rewriting content, improving structure, or targeting better keywords.\n\nCost of a wrong recommendation: If we flag a low-opportunity page as high-priority, \nwe waste time and budget refreshing something unlikely to move traffic. If we miss a \ngenuinely high-opportunity page (good search volume, poor position, low CTR), we lose \nout on traffic that could have been captured with a small effort - a real opportunity cost.\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, subprocess, sys

REPO_URL = "https://github.com/ramanchauhan2271-dev/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL])

os.chdir(REPO_DIR)
print("Working dir:", os.getcwd())

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number 1
opportunity_pages = df[(df["search_volume"] > 50) & (df["avg_position"] > 10)]
print(f"Pages with search_volume > 50 but avg_position > 10: {len(opportunity_pages)} out of {len(df)}")

# Number 2
top_ctr = df[df["avg_position"] <= 3]["ctr"].mean()
low_ctr = df[df["avg_position"] > 10]["ctr"].mean()
print(f"Average CTR (position <= 3): {top_ctr:.3f}")
print(f"Average CTR (position > 10): {low_ctr:.3f}")

# Number 3
corr = df["search_volume"].corr(df["impressions_90d"])
print(f"Correlation between search_volume and impressions_90d: {corr:.3f}")
print("This confirms: volume alone doesn't predict traffic - position and CTR matter more,")
print("which is exactly what a refresh-opportunity score should account for.")
# Out:
# Working dir: /content/flyrank-ml-internship/flyrank-ml-internship
# Pages with search_volume > 50 but avg_position > 10: 2588 out of 30000
# Average CTR (position <= 3): 1.473
# Average CTR (position > 10): 0.263
# Correlation between search_volume and impressions_90d: 0.001
# This confirms: volume alone doesn't predict traffic - position and CTR matter more,
# which is exactly what a refresh-opportunity score should account for.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"""
What I can claim (observed / directional / decision-support):
- The data shows a clear pattern: pages with decent search volume but poor position
  have much lower CTR than well-positioned pages (1.473 vs 0.263) - a real, observed gap.
- 2,588 pages currently sit in a zone where better positioning could plausibly unlock
  more clicks. This is a reasonable signal to prioritize investigation.
- A refresh-opportunity score built from this data can support a team's decision-making
  by surfacing candidates worth a closer look.

What I cannot claim:
- I cannot claim refreshing these pages will cause a specific traffic increase - this
  is correlational, not causal. Other factors (content quality, competition, seasonality)
  also affect position and CTR.
- I am not predicting how Google's algorithm will respond to any specific change.
- This is not proof any individual page will improve if refreshed - it's a prioritization
  aid, not a guarantee.
"""
# Out:
# "\nWhat I can claim (observed / directional / decision-support):\n- The data shows a clear pattern: pages with decent search volume but poor position \n  have much lower CTR than well-positioned pages (1.473 vs 0.263) - a real, observed gap.\n- 2,588 pages currently sit in a zone where better positioning could plausibly unlock \n  more clicks. This is a reasonable signal to prioritize investigation.\n- A refresh-opportunity score built from this data can support a team's decision-making \n  by surfacing candidates worth a closer look.\n\nWhat I cannot claim:\n- I cannot claim refreshing these pages will cause a specific traffic increase - this \n  is correlational, not causal. Other factors (content quality, competition, seasonality) \n  also affect position and CTR.\n- I am not predicting how Google's algorithm will respond to any specific change.\n- This is not proof any individual page will improve if refreshed - it's a prioritization \n  aid, not a guarantee.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
